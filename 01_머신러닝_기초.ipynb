# %% [markdown]
# <a href="https://colab.research.google.com/github/redinbluesky/the-lm-book/blob/main/01_머신러닝_기초.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 목차
# * [Chapter 1_2 모델](#chapter1_2)

# %% [markdown]
# ## Chapter 1.2 모델 <a class="anchor" id="chapter1_2"></a>
# 1. 모델은 일반적으로 수학 방정식으로 표현된다.
